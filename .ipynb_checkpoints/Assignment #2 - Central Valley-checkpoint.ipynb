# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
oil = pd.read_csv('Data/Inland_oil2.csv')

# %%
oil.info
# Out:
# <bound method DataFrame.info of                                      LeaseName            WellDesign  \
# 0                             Southern Pacific  Southern Pacific 11H
# 1                                      Siegfus        Siegfus 31X-22
# 2                             Southern Pacific   Southern Pacific 5H
# 3                             Southern Pacific   Southern Pacific 6H
# 4                             Southern Pacific   Southern Pacific 7H
# ...                                        ...                   ...
# 78937  Lease by Holmes Western Oil Corporation                 7-Sep
# 78938      Lease by Peoples Associated Oil Co.                     1
# 78939                                 Best Yet            Best Yet 1
# 78940             Lease by Coalinga South Pole                     1
# 78941                                        L                   NaN
#
#       WellStatus WellType WellTypeLa  \
# 0       Canceled       OG  Oil & Gas
# ...

# %%
oil.head()
# Out:
#           LeaseName            WellDesign WellStatus WellType WellTypeLa  \
# 0  Southern Pacific  Southern Pacific 11H   Canceled       OG  Oil & Gas
# 1           Siegfus        Siegfus 31X-22   Canceled       OG  Oil & Gas
# 2  Southern Pacific   Southern Pacific 5H   Canceled       OG  Oil & Gas
# 3  Southern Pacific   Southern Pacific 6H   Canceled       OG  Oil & Gas
# 4  Southern Pacific   Southern Pacific 7H   Canceled       OG  Oil & Gas
#
#                                     OperatorNa        Place CountyName  \
# 0  California Resources Production Corporation  Kern County       Kern
# 1  California Resources Production Corporation  Kern County       Kern
# 2                    Stockdale Oil & Gas, Inc.  Kern County       Kern
# 3                    Stockdale Oil & Gas, Inc.  Kern County       Kern
# 4                    Stockdale Oil & Gas, Inc.  Kern County       Kern
#
#     Latitude   Longitude GISSource isDirectio  WellSymbol
# ...

# %%
oil.head
# Out:
# <bound method NDFrame.head of                                      LeaseName            WellDesign  \
# 0                             Southern Pacific  Southern Pacific 11H
# 1                                      Siegfus        Siegfus 31X-22
# 2                             Southern Pacific   Southern Pacific 5H
# 3                             Southern Pacific   Southern Pacific 6H
# 4                             Southern Pacific   Southern Pacific 7H
# ...                                        ...                   ...
# 78937  Lease by Holmes Western Oil Corporation                 7-Sep
# 78938      Lease by Peoples Associated Oil Co.                     1
# 78939                                 Best Yet            Best Yet 1
# 78940             Lease by Coalinga South Pole                     1
# 78941                                        L                   NaN
#
#       WellStatus WellType WellTypeLa  \
# 0       Canceled       OG  Oil & Gas
# ...

# %%
oil.head()
# Out:
#           LeaseName            WellDesign WellStatus WellType WellTypeLa  \
# 0  Southern Pacific  Southern Pacific 11H   Canceled       OG  Oil & Gas
# 1           Siegfus        Siegfus 31X-22   Canceled       OG  Oil & Gas
# 2  Southern Pacific   Southern Pacific 5H   Canceled       OG  Oil & Gas
# 3  Southern Pacific   Southern Pacific 6H   Canceled       OG  Oil & Gas
# 4  Southern Pacific   Southern Pacific 7H   Canceled       OG  Oil & Gas
#
#                                     OperatorNa        Place CountyName  \
# 0  California Resources Production Corporation  Kern County       Kern
# 1  California Resources Production Corporation  Kern County       Kern
# 2                    Stockdale Oil & Gas, Inc.  Kern County       Kern
# 3                    Stockdale Oil & Gas, Inc.  Kern County       Kern
# 4                    Stockdale Oil & Gas, Inc.  Kern County       Kern
#
#     Latitude   Longitude GISSource isDirectio  WellSymbol
# ...

# %%
oil.shape
# Out:
# (78942, 13)

# %%
pd.options.display.max_info_columns
# Out:
# 100

# %%
oil.info
# Out:
# <bound method DataFrame.info of                                      LeaseName            WellDesign  \
# 0                             Southern Pacific  Southern Pacific 11H
# 1                                      Siegfus        Siegfus 31X-22
# 2                             Southern Pacific   Southern Pacific 5H
# 3                             Southern Pacific   Southern Pacific 6H
# 4                             Southern Pacific   Southern Pacific 7H
# ...                                        ...                   ...
# 78937  Lease by Holmes Western Oil Corporation                 7-Sep
# 78938      Lease by Peoples Associated Oil Co.                     1
# 78939                                 Best Yet            Best Yet 1
# 78940             Lease by Coalinga South Pole                     1
# 78941                                        L                   NaN
#
#       WellStatus WellType WellTypeLa  \
# 0       Canceled       OG  Oil & Gas
# ...

# %%
oil.columns.to_list()
# Out:
# ['LeaseName',
#  'WellDesign',
#  'WellStatus',
#  'WellType',
#  'WellTypeLa',
#  'OperatorNa',
#  'Place',
#  'CountyName',
#  'Latitude',
#  'Longitude',
#  'GISSource',
#  'isDirectio',
#  'WellSymbol']

# %%
desired_columns = ['WellStatus','CountyName','Latitude','Longitude','WellTypeLa']

# %%
oilsubset = oil[desired_columns].copy()

# %%
oilsubset
# Out:
#       WellStatus CountyName   Latitude   Longitude WellTypeLa
# 0       Canceled       Kern  35.401291 -118.860405  Oil & Gas
# 1       Canceled       Kern  35.397495 -118.855888  Oil & Gas
# 2       Canceled       Kern  35.404583 -118.850471  Oil & Gas
# 3       Canceled       Kern  35.403610 -118.849937  Oil & Gas
# 4       Canceled       Kern  35.405106 -118.856483  Oil & Gas
# ...          ...        ...        ...         ...        ...
# 78937     Active     Fresno  36.110683 -120.367996  Oil & Gas
# 78938    Plugged     Fresno  36.051788 -120.378555   Dry Hole
# 78939    Plugged     Fresno  36.103725 -120.390457   Dry Hole
# 78940    Plugged     Fresno  36.099918 -120.380226   Dry Hole
# 78941        NaN        NaN        NaN         NaN        NaN
#
# [78942 rows x 5 columns]

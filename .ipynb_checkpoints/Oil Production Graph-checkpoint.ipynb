# %% [markdown]
# This notebook takes US Energy Information Administration crude oil production data for California
# for a dataset showing production by thousands of barrels per day from 1981 to 2021. The data illuminates that oil production in the state peaked in the mid-1980s and has declined every since. Although data was not available for Kern County, we have been able to corroborate a similar trend in production with CalGEM's interactive data dashboard.

# %%
import pandas as pd
import geopandas as gpd

# %%
oilhist = pd.read_csv('historic_oil_data.csv')

# %%
oilhist.columns.to_list()
# Out:
# ['1981', '1001']

# %%
#adds column names to the data frame
df = pd.read_csv('historic_oil_data.csv', header=None)
df.columns = ['Year', 'oil_production']

# %%
df.head()
# Out:
#      Year  oil_production
# 0  1981.0          1001.0
# 1  1982.0          1022.0
# 2  1983.0          1025.0
# 3  1984.0          1043.0
# 4  1985.0          1079.0

# %%
df.dtypes
# Out:
# Year              float64
# oil_production    float64
# dtype: object

# %%
#need to convert to integer to remove .0 
df['Year'] = df['Year'].fillna(0).astype(int)
df.head()
# Out:
#    Year  oil_production
# 0  1981          1001.0
# 1  1982          1022.0
# 2  1983          1025.0
# 3  1984          1043.0
# 4  1985          1079.0

# %%
df['oil_production'] = df['oil_production'].fillna(0).astype(int)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Here I wanted to plot a the relationship between year and production amount. I found that columns would not work and so had to plot individual data points.

# %%
#for some reason, it seems you have to plot individual data points (must be an easier way)
x=['1981','1982']
y=['1001','1022']
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("A simple line graph")
plt.show()

# %% [markdown]
# To copy the data points more easily, I turned my data columns into lists.

# %%
#this turns data columns to lists
col_list = df.Year.values.tolist()
print(col_list)
# Out:
# [1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 0]

# %%
#this turns data columns to lists
col_list = df.oil_production.values.tolist()
print(col_list)
# Out:
# [1001, 1022, 1025, 1043, 1079, 1036, 999, 969, 907, 879, 875, 835, 803, 784, 764, 772, 781, 777, 748, 741, 714, 707, 680, 656, 631, 611, 599, 586, 568, 549, 537, 539, 545, 561, 551, 508, 475, 440, 428, 389, 369, 0]

# %% [markdown]
# I then graphed the relationship below which shows a drop from close to 1100 thousand barrels per day to less than 400. This could be for a number of reasons but likely among them is the cost of oil production in California as opposed to other states with less stringent regulation and lower labor costs. Additionally, environmental activism has limited oil production in places such as LA and off the Southern California coast due to a history of oil spills.

# %%
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [9, 6]
plt.rcParams["figure.autolayout"] = True

years = [1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 
         1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 
         2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021]
population = [1001, 1022, 1025, 1043, 1079, 1036, 999, 969, 907, 879, 875, 835, 803, 
              784, 764, 772, 781, 777, 748, 741, 714, 707, 680, 656, 631, 611, 599, 
              586, 568, 549, 537, 539, 545, 561, 551, 508, 475, 440, 428, 389, 369]
plt.xlabel('Year')
plt.ylabel('Thousands of barrels per day')

plt.plot(years, population, color='red')
plt.title("Crude Oil Production in California, 1981 - 2021")
plt.savefig('oil_production.png')
plt.show()

# %%
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

years = [1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 
         1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 
         2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020, 2021]
population = [1001, 1022, 1025, 1043, 1079, 1036, 999, 969, 907, 879, 875, 835, 803, 
              784, 764, 772, 781, 777, 748, 741, 714, 707, 680, 656, 631, 611, 599, 
              586, 568, 549, 537, 539, 545, 561, 551, 508, 475, 440, 428, 389, 369]
plt.xlabel('Year')
plt.ylabel('Thousands of barrels per day')

plt.plot(years, population, color='red')
plt.title("Crude Oil Production in California, 1981 - 2021")

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='green', shrink=0.05),
             )
plt.show()

# %% [markdown]
# Here I plan to map the state's petroleum consumption also using data from the US Energy Information Administration  and plotting against the production of crude oil. I am planning to complete more research to understand how commensurable these two designations (crude oil and petroleum).

# %%
oil_consumption = pd.read_csv('petroleum_consumption_ca.csv', header=None)
oil_consumption.columns = ['Year', 'petroleum_consumption']

# %%
oil_consumption.shape
# Out:
# (61, 2)

# %%
oil_consumption.head(25)
# Out:
#     Year petroleum_consumption
# 0   1960               301,475
# 1   1961               311,968
# 2   1962               318,215
# 3   1963               327,494
# 4   1964               345,532
# 5   1965               357,319
# 6   1966               376,909
# 7   1967               385,400
# 8   1968               412,224
# 9   1969               422,493
# 10  1970               429,388
# 11  1971               443,325
# 12  1972               450,913
# 13  1973               468,802
# 14  1974               451,250
# 15  1975               454,801
# 16  1976               480,622
# 17  1977               511,912
# 18  1978               548,539
# 19  1979               561,392
# 20  1980               551,178
# 21  1981               525,495
# 22  1982               500,953
# 23  1983               525,707
# 24  1984               574,559

# %%
#getting ride of 1960s-1981 so it matches production data
oil_consumption = oil_consumption.loc[21:62]

# %%
#this turns data columns to lists
col_list = oil_consumption.petroleum_consumption.values.tolist()
print(col_list)
# Out:
# ['525,495', '500,953', '525,707', '574,559', '559,771', '570,732', '597,296', '623,386', '631,523', '626,122', '588,804', '591,316', '572,584', '598,416', '601,765', '611,691', '599,179', '603,553', '622,639', '647,226', '650,434', '675,790', '651,727', '681,915', '694,230', '702,973', '707,338', '669,001', '645,460', '627,091', '614,252', '598,105', '604,446', '603,247', '625,736', '646,498', '660,096', '662,364', '659,318', '524,121']

# %% [markdown]
# The graph below shows that the use of all these figures without being rounded more generously is causing problems for the Y axis. For the final, I plan to alter these values in a way that captures them but allows the data to be displayed more clearly.

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

years = [1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 
         1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 
         2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 
         2018, 2019, 2020]
population = ['525,495', '500,953', '525,707', '574,559', '559,771', '570,732', '597,296', '623,386',
'631,523', '626,122', '588,804', '591,316', '572,584', '598,416', '601,765', '611,691', '599,179', 
'603,553', '622,639', '647,226', '650,434', '675,790', '651,727', '681,915', '694,230', '702,973', 
'707,338', '669,001', '645,460', '627,091', '614,252', '598,105', '604,446', '603,247', '625,736', 
'646,498', '660,096', '662,364', '659,318', '524,121']
plt.xlabel('Year')
plt.ylabel('Thousands of barrels per day')

plt.plot(years, population, color='red')
plt.title("Petroleum Consumption in California, 1981 - 2021")

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='green', shrink=0.05),
             )
plt.show()

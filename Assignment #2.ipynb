# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
public = gpd.read_file('Publicly-Owned_Properties.csv')

# %%
public.head
# Out:
# <bound method NDFrame.head of       OBJECTID         AIN TaxRateArea SitusHouseNo SitusFraction  \
# 0            1  2004011900          16            0
# 1            2  2004018900          16        22345
# 2            3  2004018901          16        22330
# 3            4  2004018902          16        22322
# 4            5  2004025900        2318            0
# ...        ...         ...         ...          ...           ...
# 13943    13980  7557039900         234            0
# 13944    13981  7561025902          20            0
# 13945    13982  7561044900         308            0
# 13946    13983  7562002900         308            0
# 13947    13984  7562002901         308            0
#
#       SitusDirection SitusUnit SitusStreet       SitusCity    SitusZIP  ...  \
# 0                                                                       ...
# 1                                MALDEN ST  LOS ANGELES CA  91304-2202  ...
# ...

# %%
public.type
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 13943    None
# 13944    None
# 13945    None
# 13946    None
# 13947    None
# Length: 13948, dtype: object

# %%
public.head(5)
# Out:
#   OBJECTID         AIN TaxRateArea SitusHouseNo SitusFraction SitusDirection  \
# 0        1  2004011900          16            0
# 1        2  2004018900          16        22345
# 2        3  2004018901          16        22330
# 3        4  2004018902          16        22322
# 4        5  2004025900        2318            0
#
#   SitusUnit SitusStreet       SitusCity    SitusZIP  ... State County City  \
# 0                                                    ...     0      0    1
# 1             MALDEN ST  LOS ANGELES CA  91304-2202  ...     0      0    1
# 2               NAPA ST  LOS ANGELES CA  91304-2209  ...     0      0    1
# 3               NAPA ST  LOS ANGELES CA  91304-2209  ...     0      0    1
# 4                                                    ...     0      0    1
#
#   Metro LAUSD      Shape_Length        Shape_Area          Longitude  \
# 0     0     0  2071.25834234849  259739.876953125  -118.617885560891
# ...

# %%
public.tail(4)
# Out:
#       OBJECTID         AIN TaxRateArea SitusHouseNo SitusFraction  \
# 13944    13981  7561025902          20            0
# 13945    13982  7561044900         308            0
# 13946    13983  7562002900         308            0
# 13947    13984  7562002901         308            0
#
#       SitusDirection SitusUnit SitusStreet SitusCity SitusZIP  ... State  \
# 13944                                                          ...     0
# 13945                                                          ...     0
# 13946                                                          ...     0
# 13947                                                          ...     0
#
#       County City Metro LAUSD      Shape_Length       Shape_Area  \
# 13944      0    1     0     0  3212.97267522617  624676.51171875
# 13945      0    1     0     0  487.521385586587  14853.435546875
# 13946      0    1     0     0  472.326460640536    700.345703125
# ...

# %%
public.info
# Out:
# <bound method DataFrame.info of       OBJECTID         AIN TaxRateArea SitusHouseNo SitusFraction  \
# 0            1  2004011900          16            0
# 1            2  2004018900          16        22345
# 2            3  2004018901          16        22330
# 3            4  2004018902          16        22322
# 4            5  2004025900        2318            0
# ...        ...         ...         ...          ...           ...
# 13943    13980  7557039900         234            0
# 13944    13981  7561025902          20            0
# 13945    13982  7561044900         308            0
# 13946    13983  7562002900         308            0
# 13947    13984  7562002901         308            0
#
#       SitusDirection SitusUnit SitusStreet       SitusCity    SitusZIP  ...  \
# 0                                                                       ...
# 1                                MALDEN ST  LOS ANGELES CA  91304-2202  ...
# ...

# %%
public.shape
# Out:
# (13948, 51)

# %%
traffic = gpd.read_file('Traffic_Collision_Data_from_2010_to_Present.csv')

# %%
traffic.head

# %%
traffic.summary

# %%
traffic.head(5)

# %%
traffic.tail(5)

# %%
traffic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 traffic
#
# NameError: name 'traffic' is not defined
